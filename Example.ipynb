# %% [markdown]
# ## Search for a job Description

# %% [markdown]
# The main motivations for this project were three-fold. Firstly, we aimed to explore and apply novel models in the field of Natural Language Processing (NLP), such as OpenAI embedding and MPNet from Hugging Face. Secondly, we sought to develop an application that is specifically tailored for job search. Upon inputting a job title, users would be able to obtain a list of the closest task descriptions associated with that particular job title. Lastly, we aimed to experiment with two different methods of deploying our application - Github pages and Streamlit app.
#
# The inspiration for this project came from a personal experience, where one of our team members received a suggestion from an employer to consider coordinator positions that were suitable for her resume and skills. However, she had never considered or looked for such positions before. This sparked the idea of developing an application that would be beneficial not only to her, but also to the thousands of people who are starting their career and looking for job opportunities.
#
# Furthermore, we were inspired by a lecture by Professor Ran Feldish, where he presented an application that uses OpenAI embedding to match products with product descriptions (https://github.com/ShawnTXin/openai-embeddings). This motivated us to use a similar approach, but with a different objective - matching job titles with job descriptions.
#
# The dataset used in this project was obtained from ONET Resource Center (https://www.onetcenter.org/), specifically the Task Statements Database, which provides a mapping of ONET-SOC codes (occupations) to tasks associated with the occupation.
#
# In this notebook, we will first explore OpenAI embedding and then experiment with MPNet sentence transformer.

# %% [markdown]
# ## First Model: OpenAI "text-embedding-ada-002"

# %% [markdown]
# To provide proper attribution, we would like to acknowledge that approximately 90% of the implementation of this model was adapted from "https://github.com/ShawnTXin/openai-embeddings". However, we utilized the code with our OpenAI API and applied it to a novel dataset for our project.

# %% [markdown]
# ### 1- Import the libraries

# %%
# !pip install utils openai tiktoken
import os
import time
import numpy as np
import pandas as pd

from openai.embeddings_utils import get_embedding
from openai.embeddings_utils import cosine_similarity
import tiktoken

# %%
import openai

#OpenAI API Key location
ENV_PATH = "/content/env"

def get_openai_api_key(env_path=ENV_PATH):
    # read and parse file
    with open(env_path, 'r') as f:
        lines = f.readlines()
    for line in lines:
        if line.startswith("OPENAI_API_KEY"):
            openai_api_key = line.split("=")[1].strip()
        else:
            print("Error")
    print(f'Read OpenAI API authentication key from {env_path} file')
    return openai_api_key

def openai_auth(openai_api_key:str=get_openai_api_key()):
    # authenticate with OpenAI
    openai.api_key = openai_api_key
    print(f'Set OpenAI authentication key')
    return

# %% [markdown]
# ### 2- Defining the Dataset and Model
#
# In this section, we define the input file containing the tasks for which we want to generate embeddings and the output path where we would like to save these embeddings. We also define the models that will be used for encoding and embedding.
#
# For the input data, we have specified the location of the CSV file containing the tasks we want to embed and the column name of the task description. We will use this column to generate embeddings.
#
# The output data parameters define where we want to save the embeddings generated by the embedding model.
#
# For the embedding model, we have specified the name of the pre-trained model to use and the encoding model to be used in conjunction with it. We have also set an upper limit on the number of tokens to be utilized in each input sequence. This limit is in accordance with the guidelines presented in "https://platform.openai.com/docs/guides/embeddings/what-are-embeddings".

# %%
# input data parameters
DOCUMENT_PATH = "/content/Task Statements(1).xlsx"
COLUMN_TO_EMBED = "Task"

# output data parameters
OUTPUT_PATH = "/content/drive/MyDrive/TaskEmbeddings_boshra.csv"

#embedding model parameters
EMBEDDING_MODEL = "text-embedding-ada-002"
ENCODING_MODEL = "cl100k_base"  # this is the encoding for text-embedding-ada-002
MAX_TOKENS = 8191  # the maximum for text-embedding-ada-oo2 is 8191

print(f'Using embedding model: {EMBEDDING_MODEL}')
print(f'Using encoding: {ENCODING_MODEL}')
print(f'Maximum number of tokens: {MAX_TOKENS}')
print('***********************************')
df = pd.read_excel(DOCUMENT_PATH)
print(f'Read {len(df)} documents from {DOCUMENT_PATH}')
#Print samples from the dataset
df.head(10)

# %%
#Print the samples from the 'Task' column that will be used to generate embeddings
print(df['Title'].values[0],"Tasks")
print(df['Task'].values[:3])
df[['Task']].head()
# Out:
# Chief Executives Tasks
# ["Direct or coordinate an organization's financial or budget activities to fund operations, maximize investments, or increase efficiency."
#  'Appoint department heads or managers and assign or delegate responsibilities to them.'
#  'Analyze operations to evaluate performance of a company or its staff in meeting objectives or to determine areas of potential cost reduction, program improvement, or policy change.']
#                                                 Task
# 0  Direct or coordinate an organization's financi...
# 1  Appoint department heads or managers and assig...
# 2  Analyze operations to evaluate performance of ...
# 3  Direct, plan, or implement policies, objective...
# 4  Prepare budgets for approval, including those ...

# %% [markdown]
# ### 3- Generate Encodings
# In this section, we utilize the encoding model that is associated with the embedding model "text-embedding-ada-002". Encoding is performed to ensure two benefits. Firstly, it confirms that the number of tokens is less than the maximum tokens that the embedding model accepts. Secondly, it provides an estimate of the pricing when using the embedding model since usage is priced per input token.
#
# We added the encoding of the "task" column to the original data and ensured that there were no encodings that exceed the maximum token limit set by the embedding model. This step is important as it prevents any loss of data during the subsequent steps of the project.

# %%
# tokenize: generate encodings for 'cloumn_to_embed'
encoding = tiktoken.get_encoding(ENCODING_MODEL)
df["encoding"] = df[COLUMN_TO_EMBED].apply(lambda x: encoding.encode(x))
print(f'Encoded the {COLUMN_TO_EMBED} column into an encoding column')
df.head()
# Out:
# Encoded the Task column into an encoding column
#   O*NET-SOC Code             Title  Task ID  \
# 0     11-1011.00  Chief Executives     8823
# 1     11-1011.00  Chief Executives     8831
# 2     11-1011.00  Chief Executives     8825
# 3     11-1011.00  Chief Executives     8826
# 4     11-1011.00  Chief Executives     8827
#
#                                                 Task Task Type  \
# 0  Direct or coordinate an organization's financi...      Core
# 1  Appoint department heads or managers and assig...      Core
# 2  Analyze operations to evaluate performance of ...      Core
# 3  Direct, plan, or implement policies, objective...      Core
# 4  Prepare budgets for approval, including those ...      Core
#
#    Incumbents Responding     Date Domain Source  \
# 0                   87.0  07/2014     Incumbent
# 1                   87.0  07/2014     Incumbent
# 2                   87.0  07/2014     Incumbent
# 3                   87.0  07/2014     Incumbent
# 4                   87.0  07/2014     Incumbent
#
#                                             encoding
# 0  [16411, 477, 16580, 459, 7471, 596, 6020, 477,...
# 1  [2213, 787, 9476, 14971, 477, 20258, 323, 9993...
# 2  [2127, 56956, 7677, 311, 15806, 5178, 315, 264...
# 3  [16411, 11, 3197, 11, 477, 4305, 10396, 11, 26...
# 4  [51690, 42484, 369, 14765, 11, 2737, 1884, 369...

# %%
# omit encodings that are too long to embed
df["n_tokens"] = df.encoding.apply(lambda x: len(x))
n_long_encodings = len(df[df.n_tokens > MAX_TOKENS])
df = df[df.n_tokens <= MAX_TOKENS]
print(f'Omitted {n_long_encodings} encodings that were too long to embed')
# Out:
# Omitted 0 encodings that were too long to embed

# %% [markdown]
# ### 4- Generate Embeddings
#
# In this section, we focus on the core building block of our project, which is the embedding model. Based on the recommendation from OpenAI, we used the "text-embedding-ada-002" model for nearly all use cases, and we found it to be better, cheaper, and simpler to use. However, we did encounter some issues with the computation time, which could be attributed to the size of our dataset (19265 sentences) and the computing power of our device. To validate this, we tested the model on a smaller sample size of 1000 sentences, and it was much faster.
#
# It's important to note that in order to use the embedding model from OpenAI, we had to obtain an OpenAI API key, which needed to be checked and authorized. Once the API key was validated, we were able to use the embedding model accurately and without any errors.
#
# Additionally, we want to emphasize that we did not pay to use the embedding model. We obtained the OpenAI API key from the official website (https://platform.openai.com/account/api-keys), but it required creating an account to get the API key.

# %%
openai_auth()

# embed: generate embeddings for 'column_to_embed', by calling the OpenAI API
print(f'Embedded {COLUMN_TO_EMBED} into an embedding column, by calling the OpenAI API')
print(f'This will take some time for {len(df)} documents...')
df["embedding"] = df[COLUMN_TO_EMBED].apply(lambda x: get_embedding(x, engine=EMBEDDING_MODEL))
# Out:
# Set OpenAI authentication key
# Embedded Task into an embedding column, by calling the OpenAI API
# This may take about a minute for 19265 documents...

# %%
# save embeddings to output_path
df.to_csv(OUTPUT_PATH, index=False)
print(f'Saved embeddings to {OUTPUT_PATH}')
# Out:
# Saved embeddings to data/TaskEmbeddingss.csv

# %%
file_path = "/content/drive/MyDrive/TaskEmbeddings_boshra.csv"  # a folder with all the documents embeddings. within this folder, one csv file include multiple documents embedding of the same run
COLUMN_EMBEDDINGS = "embedding"  # the embedding column name in the documents embedding file.

# %%
# read documents embeddings
df = pd.read_csv(file_path)
df[COLUMN_EMBEDDINGS] = df[COLUMN_EMBEDDINGS].apply(eval).apply(np.array) # convert string to np array
print(f'Read {len(df)} documents embeddings from {file_path}')
# Out:
# Read 19265 documents embeddings from /content/drive/MyDrive/TaskEmbeddings_boshra.csv

# %% [markdown]
# ### 5- Testing the model

# %% [markdown]
# #### First example: Nurse

# %%
openai_auth()
query=""
print('***********************************')
query = "Nurse" 
tic = time.time()
query_embedding = get_embedding(query, engine=EMBEDDING_MODEL)
toc = time.time()
print(f'Embedding {query} took {round(toc-tic)*1000}ms')
print(f'Top matches for {query} ordered by cosine similarity of vector embeddings:')
df['similarity'] = df[COLUMN_EMBEDDINGS].apply(lambda x: cosine_similarity(x, query_embedding))
#print(df.sort_values(by='similarity', ascending=False)[['Title','Task','similarity' ]].head(10))
df.sort_values(by='similarity', ascending=False)[['Title','Task','similarity' ]].head(10)
# Out:
# Set OpenAI authentication key
# ***********************************
# Embedding Nurse took 1000ms
# Top matches for Nurse ordered by cosine similarity of vector embeddings:
#                                                    Title  \
# 9294                                          Urologists
# 8807                                   Registered Nurses
# 10218                                  Psychiatric Aides
# 8650                              Respiratory Therapists
# 8975                                      Nurse Midwives
# 9859   Licensed Practical and Licensed Vocational Nurses
# 8891                                Critical Care Nurses
# 9041                                   Anesthesiologists
# 10170                                 Nursing Assistants
# 9278                                        Hospitalists
#
#                                                     Task  similarity
# 9294   Direct the work of nurses, residents, or other...    0.866371
# 8807   Observe nurses and visit patients to ensure pr...    0.864399
# 10218  Perform nursing duties, such as administering ...    0.863363
# 8650   Work as part of a team of physicians, nurses, ...    0.862016
# 8975   Plan, provide, or evaluate educational program...    0.861606
# 9859              Supervise nurses' aides or assistants.    0.861478
# 8891           Supervise and monitor unit nursing staff.    0.859506
# 9041   Coordinate and direct work of nurses, medical ...    0.858469
# 10170  Assist nurses or physicians in the operation o...    0.858173
# 9278   Direct, coordinate, or supervise the patient c...    0.857854

# %% [markdown]
# #### Second example: Data Scientist

# %%
openai_auth()
query=""
print('***********************************')
query = "Data Scientist"
tic = time.time()
query_embedding = get_embedding(query, engine=EMBEDDING_MODEL)
toc = time.time()
print(f'Embedding {query} took {round(toc-tic)*1000}ms')
print(f'Top matches for {query} ordered by cosine similarity of vector embeddings:')
df['similarity'] = df[COLUMN_EMBEDDINGS].apply(lambda x: cosine_similarity(x, query_embedding))
#print(df.sort_values(by='similarity', ascending=False)[['Title','Task','similarity' ]].head(10))
df.sort_values(by='similarity', ascending=False)[['Title','Task','similarity' ]].head(10)
# Out:
# Set OpenAI authentication key
# ***********************************
# Embedding Data Scientist took 0ms
# Top matches for Data Scientist ordered by cosine similarity of vector embeddings:
#                                    Title  \
# 2997          Bioinformatics Technicians
# 2917                    Biostatisticians
# 2932                     Data Scientists
# 5338  Social Science Research Assistants
# 5341  Social Science Research Assistants
# 2905                       Statisticians
# 2951      Business Intelligence Analysts
# 2895                       Statisticians
# 2986          Bioinformatics Technicians
# 2991          Bioinformatics Technicians
#
#                                                    Task  similarity
# 2997  Develop or apply data mining and machine learn...    0.869527
# 2917     Develop or implement data analysis algorithms.    0.864632
# 2932  Analyze, manipulate, or process large sets of ...    0.863898
# 5338  Design and create special programs for tasks s...    0.852801
# 5341  Perform descriptive and multivariate statistic...    0.851475
# 2905  Develop software applications or programming f...    0.849103
# 2951  Create business intelligence tools or systems,...    0.846382
# 2895  Process large amounts of data for statistical ...    0.846101
# 2986  Analyze or manipulate bioinformatics data usin...    0.845648
# 2991  Develop or maintain applications that process ...    0.845227

# %% [markdown]
# #### Third Example: Ask the user for a job title

# %%
openai_auth()
query=""
print('***********************************')
query = input('Please enter a Job Title: ') # get query from user
tic = time.time()
query_embedding = get_embedding(query, engine=EMBEDDING_MODEL)
toc = time.time()
print(f'Embedding query took {round(toc-tic)*1000}ms')
print(f'Top matches for {query} ordered by cosine similarity of vector embeddings:')
df['similarity'] = df[COLUMN_EMBEDDINGS].apply(lambda x: cosine_similarity(x, query_embedding))
#print(df.sort_values(by='similarity', ascending=False)[['Title','Task','similarity' ]].head(10))
df.sort_values(by='similarity', ascending=False)[['Title','Task','similarity' ]].head(10)
# Out:
# Set OpenAI authentication key
# ***********************************
# Please enter a Job Title: Mechanical Engineer
# Embedding query took 1000ms
# Top matches for Mechanical Engineer ordered by cosine similarity of vector embeddings:
#                                                    Title  \
# 4017   Electro-Mechanical and Mechatronics Technologi...
# 4127   Mechanical Engineering Technologists and Techn...
# 4150   Mechanical Engineering Technologists and Techn...
# 18767                          Sailors and Marine Oilers
# 4014   Electro-Mechanical and Mechatronics Technologi...
# 15885            Maintenance and Repair Workers, General
# 3542                                Mechanical Engineers
# 4018   Electro-Mechanical and Mechatronics Technologi...
# 3997   Electro-Mechanical and Mechatronics Technologi...
# 16035  Helpers--Installation, Maintenance, and Repair...
#
#                                                     Task  similarity
# 4017   Assist engineers to implement electromechanica...    0.882823
# 4127   Provide technical support to other employees r...    0.873477
# 4150   Devise, fabricate, or assemble new or modified...    0.873453
# 18767  Provide engineers with assistance in repairing...    0.872678
# 4014   Translate electromechanical drawings into desi...    0.872547
# 15885  Design new equipment to aid in the repair or m...    0.872355
# 3542   Research, design, evaluate, install, operate, ...    0.872036
# 4018   Consult with machinists to ensure that electro...    0.870969
# 3997   Fabricate or assemble mechanical, electrical, ...    0.870386
# 16035  Design, weld, and fabricate parts, using bluep...    0.869464

# %% [markdown]
# ### 6- Evaluating the model:

# %%
unique_job_titles = job['Title'].unique()

# randomly select 10 unique job titles
random_job_titles = np.random.choice(unique_job_titles, size=50, replace=False)

print(random_job_titles)
# Out:
# ['Petroleum Pump System Operators, Refinery Operators, and Gaugers'
#  'Information Security Engineers' 'Advertising Sales Agents'
#  'Crane and Tower Operators'
#  'Extruding and Forming Machine Setters, Operators, and Tenders, Synthetic and Glass Fibers'
#  'Animal Caretakers' 'Naturopathic Physicians'
#  'Biomass Power Plant Managers' 'Tapers' 'Cargo and Freight Agents'
#  'Sociologists' 'Gas Plant Operators' 'Social Science Research Assistants'
#  'Urologists' 'New Accounts Clerks'
#  'Camera Operators, Television, Video, and Film'
#  'Licensed Practical and Licensed Vocational Nurses'
#  'Timing Device Assemblers and Adjusters'
#  'Dining Room and Cafeteria Attendants and Bartender Helpers'
#  'Tailors, Dressmakers, and Custom Sewers'
#  'Environmental Science and Protection Technicians, Including Health'
#  'Environmental Science Teachers, Postsecondary'
#  'Plating Machine Setters, Operators, and Tenders, Metal and Plastic'
#  'Helpers--Brickmasons, Blockmasons, Stonemasons, and Tile and Marble Setters'
#  'Special Education Teachers, Preschool' 'Nuclear Technicians'
#  'Biostatisticians' 'Radiation Therapists' 'Database Administrators'
#  'Layout Workers, Metal and Plastic' 'Histotechnologists'
#  'Wind Energy Operations Managers' 'Business Teachers, Postsecondary'
#  'Buyers and Purchasing Agents, Farm Products'
#  'Social and Community Service Managers'
#  'Radio Frequency Identification Device Specialists'
#  'Hydroelectric Plant Technicians' 'Exercise Physiologists'
#  'Water Resource Specialists'
#  'First-Line Supervisors of Production and Operating Workers'
#  'Dentists, General'
#  'Cooling and Freezing Equipment Operators and Tenders'
#  'Equal Opportunity Representatives and Officers'
#  'Transportation Inspectors' 'Urban and Regional Planners'
#  'First-Line Supervisors of Non-Retail Sales Workers'
#  'Reinforcing Iron and Rebar Workers'
#  'Purchasing Agents, Except Wholesale, Retail, and Farm Products'
#  'Machine Feeders and Offbearers'
#  'Calibration Technologists and Technicians']

# %%
sum_FirstModel=0
for title in random_job_titles:
  
  query_embedding = get_embedding(title, engine=EMBEDDING_MODEL)
  toc = time.time()
  #print(f'Embedding {title} took {round(toc-tic)*1000}ms')
  #print('Top matches ordered by cosine similarity of vector embeddings:')
  df['similarity'] = df[COLUMN_EMBEDDINGS].apply(lambda x: cosine_similarity(x, query_embedding))
  df2=df.sort_values(by='similarity', ascending=False)[['Title','Task','similarity' ]].head(10)
  predicted_titles=df2['Title'].tolist()
  count=0
  for job_title in predicted_titles:
    if title in  job_title:
      count=count+1
  sum_FirstModel=sum_FirstModel+count
  print("input title:",title,"top 10 predicted titles:",predicted_titles,count)
# Out:
# input title: Petroleum Pump System Operators, Refinery Operators, and Gaugers top 10 predicted titles: ['Petroleum Pump System Operators, Refinery Operators, and Gaugers', 'Wellhead Pumpers', 'Rail Yard Engineers, Dinkey Operators, and Hostlers', 'Wellhead Pumpers', 'Petroleum Pump System Operators, Refinery Operators, and Gaugers', 'Pump Operators, Except Wellhead Pumpers', 'First-Line Supervisors of Production and Operating Workers', 'Wellhead Pumpers', 'Derrick Operators, Oil and Gas', 'Ship Engineers'] 2
# input title: Information Security Engineers top 10 predicted titles: ['Information Security Engineers', 'Security Management Specialists', 'Network and Computer Systems Administrators', 'Web Developers', 'Information Security Engineers', 'Information Security Engineers', 'Information Security Engineers', 'Information Security Engineers', 'Information Security Engineers', 'Security Management Specialists'] 6
# input title: Advertising Sales Agents top 10 predicted titles: ['Advertising and Promotions Managers', 'Hosts and Hostesses, Restaurant, Lounge, and Coffee Shop', 'Writers and Authors', 'Advertising Sales Agents', 'Advertising Sales Agents', 'Writers and Authors', 'Writers and Authors', 'Advertising and Promotions Managers', 'Public Relations Specialists', 'Advertising and Promotions Managers'] 2
# input title: Crane and Tower Operators top 10 predicted titles: ['Explosives Workers, Ordnance Handling Experts, and Blasters', 'Earth Drillers, Except Oil and Gas', 'Furnace, Kiln, Oven, Drier, and Kettle Operators and Tenders', 'Electromechanical Equipment Assemblers', 'Cutting and Slicing Machine Setters, Operators, and Tenders', 'Hazardous Materials Removal Workers', 'Radio, Cellular, and Tower Equipment Installers and Repairers', 'Electric Motor, Power Tool, and Related Repairers', 'Boilermakers', 'Structural Metal Fabricators and Fitters'] 0
# input title: Extruding and Forming Machine Setters, Operators, and Tenders, Synthetic and Glass Fibers top 10 predicted titles: ['Extruding and Forming Machine Setters, Operators, and Tenders, Synthetic and Glass Fibers', 'Extruding and Forming Machine Setters, Operators, and Tenders, Synthetic and Glass Fibers', 'Extruding and Forming Machine Setters, Operators, and Tenders, Synthetic and Glass Fibers', 'Cutting and Slicing Machine Setters, Operators, and Tenders', 'Textile Winding, Twisting, and Drawing Out Machine Setters, Operators, and Tenders', 'Print Binding and Finishing Workers', 'Glass Blowers, Molders, Benders, and Finishers', 'Textile Knitting and Weaving Machine Setters, Operators, and Tenders', 'Extruding and Forming Machine Setters, Operators, and Tenders, Synthetic and Glass Fibers', 'Cutting, Punching, and Press Machine Setters, Operators, and Tenders, Metal and Plastic'] 4
# input title: Animal Caretakers top 10 predicted titles: ['Veterinarians', 'Animal Trainers', 'Animal Caretakers', 'Veterinary Technologists and Technicians', 'Animal Control Workers', 'Natural Sciences Managers', 'Animal Breeders', 'Veterinarians', 'First-Line Supervisors of Farming, Fishing, and Forestry Workers', 'Animal Control Workers'] 1
# input title: Naturopathic Physicians top 10 predicted titles: ['Naturopathic Physicians', 'Midwives', 'Naturopathic Physicians', 'Massage Therapists', 'Physicians, Pathologists', 'Veterinarians', 'Neurologists', 'Naturopathic Physicians', 'Chiropractors', 'Naturopathic Physicians'] 4
# input title: Biomass Power Plant Managers top 10 predicted titles: ['Biomass Power Plant Managers', 'Biomass Power Plant Managers', 'Biomass Plant Technicians', 'Biomass Power Plant Managers', 'Biofuels Production Managers', 'Biofuels Production Managers', 'Biomass Power Plant Managers', 'Biomass Power Plant Managers', 'Biomass Plant Technicians', 'Biofuels Production Managers'] 5
# input title: Tapers top 10 predicted titles: ['Molders, Shapers, and Casters, Except Metal and Plastic', 'Structural Metal Fabricators and Fitters', 'Tapers', 'Shoe and Leather Workers and Repairers', 'Glass Blowers, Molders, Benders, and Finishers', 'Helpers--Production Workers', 'Tailors, Dressmakers, and Custom Sewers', 'Heating, Air Conditioning, and Refrigeration Mechanics and Installers', 'Pipelayers', 'Timing Device Assemblers and Adjusters'] 1
# input title: Cargo and Freight Agents top 10 predicted titles: ['Customs Brokers', 'Cargo and Freight Agents', 'Freight Forwarders', 'Cargo and Freight Agents', 'Reservation and Transportation Ticket Agents and Travel Clerks', 'Logistics Analysts', 'Aircraft Service Attendants', 'Railroad Conductors and Yardmasters', 'Aircraft Cargo Handling Supervisors', 'Aircraft Cargo Handling Supervisors'] 2
# input title: Sociologists top 10 predicted titles: ['Sociologists', 'Sociologists', 'Sociologists', 'Child, Family, and School Social Workers', 'Sociologists', 'Healthcare Social Workers', 'Anthropologists and Archeologists', 'Industrial Ecologists', 'Geographers', 'Public Relations Managers'] 4
# input title: Gas Plant Operators top 10 predicted titles: ['Geothermal Production Managers', 'Gas Plant Operators', 'Wellhead Pumpers', 'Gas Plant Operators', 'Power Plant Operators', 'Biomass Power Plant Managers', 'Power Plant Operators', 'Nuclear Power Reactor Operators', 'Geothermal Production Managers', 'Geothermal Production Managers'] 2
# input title: Social Science Research Assistants top 10 predicted titles: ['Child, Family, and School Social Workers', 'Teaching Assistants, Postsecondary', 'Speech-Language Pathology Assistants', 'Healthcare Social Workers', 'Education Teachers, Postsecondary', 'Economists', 'Mental Health Counselors', 'Speech-Language Pathologists', 'Biostatisticians', 'Sociologists'] 0
# input title: Urologists top 10 predicted titles: ['Urologists', 'Urologists', 'Urologists', 'Nurse Practitioners', 'Physicians, Pathologists', 'Neurologists', 'Midwives', 'Acute Care Nurses', 'Cardiologists', 'Urologists'] 4
# input title: New Accounts Clerks top 10 predicted titles: ['Gambling Cage Workers', 'Office Clerks, General', 'Gambling Cage Workers', 'Veterinary Technologists and Technicians', 'New Accounts Clerks', 'Cooks, Institution and Cafeteria', 'New Accounts Clerks', 'Secretaries and Administrative Assistants, Except Legal, Medical, and Executive', 'Physical Therapist Aides', 'Physical Therapist Assistants'] 2
# input title: Camera Operators, Television, Video, and Film top 10 predicted titles: ['Camera Operators, Television, Video, and Film', 'Camera Operators, Television, Video, and Film', 'Media Technical Directors/Managers', 'Camera Operators, Television, Video, and Film', 'Photographic Process Workers and Processing Machine Operators', 'Camera Operators, Television, Video, and Film', 'Audio and Video Technicians', 'Broadcast Technicians', 'Producers and Directors', 'Camera Operators, Television, Video, and Film'] 5
# input title: Licensed Practical and Licensed Vocational Nurses top 10 predicted titles: ['Personal Care Aides', 'Registered Nurses', 'Licensed Practical and Licensed Vocational Nurses', 'Nurse Practitioners', 'Registered Nurses', 'Nursing Assistants', 'Clinical Nurse Specialists', 'Nurse Midwives', 'Licensed Practical and Licensed Vocational Nurses', 'Phlebotomists'] 2
# input title: Timing Device Assemblers and Adjusters top 10 predicted titles: ['Control and Valve Installers and Repairers, Except Mechanical Door', 'Watch and Clock Repairers', 'Watch and Clock Repairers', 'Electromechanical Equipment Assemblers', 'Timing Device Assemblers and Adjusters', 'Construction Laborers', 'Camera and Photographic Equipment Repairers', 'Timing Device Assemblers and Adjusters', 'Electric Motor, Power Tool, and Related Repairers', 'Mobile Heavy Equipment Mechanics, Except Engines'] 2
# input title: Dining Room and Cafeteria Attendants and Bartender Helpers top 10 predicted titles: ['Hosts and Hostesses, Restaurant, Lounge, and Coffee Shop', 'Dining Room and Cafeteria Attendants and Bartender Helpers', 'Hosts and Hostesses, Restaurant, Lounge, and Coffee Shop', 'Concierges', 'Cooks, Institution and Cafeteria', 'Waiters and Waitresses', 'Food Service Managers', 'Dining Room and Cafeteria Attendants and Bartender Helpers', 'Hosts and Hostesses, Restaurant, Lounge, and Coffee Shop', 'First-Line Supervisors of Food Preparation and Serving Workers'] 2
# input title: Tailors, Dressmakers, and Custom Sewers top 10 predicted titles: ['Costume Attendants', 'Fashion Designers', 'Tailors, Dressmakers, and Custom Sewers', 'Tailors, Dressmakers, and Custom Sewers', 'Tailors, Dressmakers, and Custom Sewers', 'Tailors, Dressmakers, and Custom Sewers', 'Tailors, Dressmakers, and Custom Sewers', 'Fashion Designers', 'Fashion Designers', 'Upholsterers'] 5
# input title: Environmental Science and Protection Technicians, Including Health top 10 predicted titles: ['Environmental Scientists and Specialists, Including Health', 'Biological Technicians', 'Environmental Science and Protection Technicians, Including Health', 'Construction Managers', 'Environmental Engineers', 'Environmental Engineering Technologists and Technicians', 'Environmental Engineers', 'Environmental Engineering Technologists and Technicians', 'Environmental Restoration Planners', 'Brownfield Redevelopment Specialists and Site Managers'] 1
# input title: Environmental Science Teachers, Postsecondary top 10 predicted titles: ['Environmental Economists', 'Environmental Scientists and Specialists, Including Health', 'Park Naturalists', 'Atmospheric and Space Scientists', 'Environmental Science Teachers, Postsecondary', 'Geography Teachers, Postsecondary', 'Biological Technicians', 'Climate Change Policy Analysts', 'Environmental Engineers', 'Foresters'] 1
# input title: Plating Machine Setters, Operators, and Tenders, Metal and Plastic top 10 predicted titles: ['Plating Machine Setters, Operators, and Tenders, Metal and Plastic', 'Molding, Coremaking, and Casting Machine Setters, Operators, and Tenders, Metal and Plastic', 'Cutting, Punching, and Press Machine Setters, Operators, and Tenders, Metal and Plastic', 'Multiple Machine Tool Setters, Operators, and Tenders, Metal and Plastic', 'Computer Numerically Controlled Tool Operators', 'Engine and Other Machine Assemblers', 'Welders, Cutters, Solderers, and Brazers', 'Machinists', 'Calibration Technologists and Technicians', 'Electro-Mechanical and Mechatronics Technologists and Technicians'] 1
# input title: Helpers--Brickmasons, Blockmasons, Stonemasons, and Tile and Marble Setters top 10 predicted titles: ['Helpers--Brickmasons, Blockmasons, Stonemasons, and Tile and Marble Setters', 'Construction Laborers', 'Stonemasons', 'Brickmasons and Blockmasons', 'Brickmasons and Blockmasons', 'Maintenance and Repair Workers, General', 'Stone Cutters and Carvers, Manufacturing', 'Helpers--Brickmasons, Blockmasons, Stonemasons, and Tile and Marble Setters', 'Stonemasons', 'Stonemasons'] 2
# input title: Special Education Teachers, Preschool top 10 predicted titles: ['Special Education Teachers, Preschool', 'Preschool Teachers, Except Special Education', 'Special Education Teachers, Preschool', 'Special Education Teachers, Elementary School', 'Special Education Teachers, Preschool', 'Special Education Teachers, Kindergarten', 'Special Education Teachers, Middle School', 'Special Education Teachers, Kindergarten', 'Special Education Teachers, Preschool', 'Special Education Teachers, Elementary School'] 4
# input title: Nuclear Technicians top 10 predicted titles: ['Nuclear Medicine Technologists', 'Radiologists', 'Nuclear Power Reactor Operators', 'Nuclear Technicians', 'Nanosystems Engineers', 'Nuclear Engineers', 'Nuclear Engineers', 'Biologists', 'Nuclear Technicians', 'Nuclear Power Reactor Operators'] 2
# input title: Biostatisticians top 10 predicted titles: ['Biostatisticians', 'Biostatisticians', 'Biostatisticians', 'Bioinformatics Technicians', 'Clinical Data Managers', 'Biostatisticians', 'Financial Risk Specialists', 'Data Scientists', 'Bioinformatics Technicians', 'Social Science Research Assistants'] 4
# input title: Radiation Therapists top 10 predicted titles: ['Medical Dosimetrists', 'Radiation Therapists', 'Radiation Therapists', 'Radiation Therapists', 'Radiologists', 'Medical Dosimetrists', 'Radiologists', 'Nuclear Medicine Technologists', 'Nuclear Medicine Technologists', 'Medical Dosimetrists'] 3
# input title: Database Administrators top 10 predicted titles: ['Database Administrators', 'Forest and Conservation Technicians', 'Social Science Research Assistants', 'Secretaries and Administrative Assistants, Except Legal, Medical, and Executive', 'Database Administrators', 'Purchasing Managers', 'Database Architects', 'Database Administrators', 'Bioinformatics Technicians', 'Library Technicians'] 3
# input title: Layout Workers, Metal and Plastic top 10 predicted titles: ['Layout Workers, Metal and Plastic', 'Layout Workers, Metal and Plastic', 'Mobile Heavy Equipment Mechanics, Except Engines', 'Jewelers and Precious Stone and Metal Workers', 'Museum Technicians and Conservators', 'Medical Appliance Technicians', 'Machinists', 'Mechanical Engineering Technologists and Technicians', 'Sheet Metal Workers', 'Machinists'] 2
# input title: Histotechnologists top 10 predicted titles: ['Physicians, Pathologists', 'Histotechnologists', 'Microbiologists', 'Medical and Clinical Laboratory Technicians', 'Biologists', 'Histotechnologists', 'Histology Technicians', 'Histotechnologists', 'Medical and Clinical Laboratory Technologists', 'Physicians, Pathologists'] 3
# input title: Wind Energy Operations Managers top 10 predicted titles: ['Wind Turbine Service Technicians', 'Wind Energy Development Managers', 'Wind Energy Operations Managers', 'Energy Engineers, Except Wind and Solar', 'Wind Energy Operations Managers', 'Wind Energy Engineers', 'Wind Energy Development Managers', 'Wind Energy Operations Managers', 'Wind Energy Engineers', 'Biofuels Production Managers'] 3
# input title: Business Teachers, Postsecondary top 10 predicted titles: ['Educational, Guidance, and Career Counselors and Advisors', 'Instructional Coordinators', 'Area, Ethnic, and Cultural Studies Teachers, Postsecondary', 'Career/Technical Education Teachers, Postsecondary', 'Career/Technical Education Teachers, Secondary School', 'Special Education Teachers, Secondary School', 'Secondary School Teachers, Except Special and Career/Technical Education', 'Family and Consumer Sciences Teachers, Postsecondary', 'Psychology Teachers, Postsecondary', 'Law Teachers, Postsecondary'] 0
# input title: Buyers and Purchasing Agents, Farm Products top 10 predicted titles: ['Buyers and Purchasing Agents, Farm Products', 'Buyers and Purchasing Agents, Farm Products', 'Farmers, Ranchers, and Other Agricultural Managers', 'Farm and Home Management Educators', 'Farm and Home Management Educators', 'Farm Labor Contractors', 'Agricultural Inspectors', 'Animal Breeders', 'Fishing and Hunting Workers', 'Purchasing Managers'] 2
# input title: Social and Community Service Managers top 10 predicted titles: ['Healthcare Social Workers', 'Mental Health and Substance Abuse Social Workers', 'First-Line Supervisors of Entertainment and Recreation Workers, Except Gambling Services', 'Farm and Home Management Educators', 'Marriage and Family Therapists', 'Administrative Services Managers', 'Child, Family, and School Social Workers', 'Medical and Health Services Managers', 'Psychiatrists', 'Chief Sustainability Officers'] 0
# input title: Radio Frequency Identification Device Specialists top 10 predicted titles: ['Radio Frequency Identification Device Specialists', 'Radio Frequency Identification Device Specialists', 'Radio Frequency Identification Device Specialists', 'Radio Frequency Identification Device Specialists', 'Radio Frequency Identification Device Specialists', 'Radio Frequency Identification Device Specialists', 'Radio Frequency Identification Device Specialists', 'Radio Frequency Identification Device Specialists', 'Radio Frequency Identification Device Specialists', 'Radio Frequency Identification Device Specialists'] 10
# input title: Hydroelectric Plant Technicians top 10 predicted titles: ['Hydroelectric Production Managers', 'Hydroelectric Plant Technicians', 'Hydroelectric Plant Technicians', 'Hydroelectric Production Managers', 'Hydroelectric Production Managers', 'Hydroelectric Plant Technicians', 'Hydroelectric Production Managers', 'Hydroelectric Plant Technicians', 'Hydroelectric Production Managers', 'Hydroelectric Production Managers'] 4
# input title: Exercise Physiologists top 10 predicted titles: ['Exercise Physiologists', 'Coaches and Scouts', 'Sports Medicine Physicians', 'Sports Medicine Physicians', 'Exercise Physiologists', 'Physical Therapists', 'Exercise Physiologists', 'Exercise Trainers and Group Fitness Instructors', 'Massage Therapists', 'Sports Medicine Physicians'] 3
# input title: Water Resource Specialists top 10 predicted titles: ['Hydrologic Technicians', 'Agricultural Engineers', 'Hydrologists', 'Conservation Scientists', 'Water Resource Specialists', 'Water/Wastewater Engineers', 'Water/Wastewater Engineers', 'Hydrologists', 'Water Resource Specialists', 'Water Resource Specialists'] 3
# input title: First-Line Supervisors of Production and Operating Workers top 10 predicted titles: ['First-Line Supervisors of Production and Operating Workers', 'Water and Wastewater Treatment Plant and System Operators', 'Mechanical Engineers', 'Agricultural Engineers', 'Chemical Plant and System Operators', 'Audio and Video Technicians', 'Industrial Engineering Technologists and Technicians', 'Industrial Production Managers', 'Farm Labor Contractors', 'Wellhead Pumpers'] 1
# input title: Dentists, General top 10 predicted titles: ['Prosthodontists', 'Dentists, General', 'Veterinary Technologists and Technicians', 'Dental Assistants', 'Dentists, General', 'Dental Hygienists', 'Dental Hygienists', 'Dentists, General', 'Dental Assistants', 'Dental Hygienists'] 3
# input title: Cooling and Freezing Equipment Operators and Tenders top 10 predicted titles: ['Cooling and Freezing Equipment Operators and Tenders', 'Stationary Engineers and Boiler Operators', 'Pump Operators, Except Wellhead Pumpers', 'Heat Treating Equipment Setters, Operators, and Tenders, Metal and Plastic', 'Baristas', 'Rolling Machine Setters, Operators, and Tenders, Metal and Plastic', 'Fast Food and Counter Workers', 'Stockers and Order Fillers', 'Heavy and Tractor-Trailer Truck Drivers', 'Amusement and Recreation Attendants'] 1
# input title: Equal Opportunity Representatives and Officers top 10 predicted titles: ['Equal Opportunity Representatives and Officers', 'Equal Opportunity Representatives and Officers', 'Equal Opportunity Representatives and Officers', 'Equal Opportunity Representatives and Officers', 'Equal Opportunity Representatives and Officers', 'Equal Opportunity Representatives and Officers', 'Equal Opportunity Representatives and Officers', 'Compensation and Benefits Managers', 'Human Resources Managers', 'Human Resources Specialists'] 7
# input title: Transportation Inspectors top 10 predicted titles: ['Transportation Engineers', 'Electrical Power-Line Installers and Repairers', 'Transportation Vehicle, Equipment and Systems Inspectors, Except Aviation', 'Transportation Engineers', 'Construction and Building Inspectors', 'Transportation Vehicle, Equipment and Systems Inspectors, Except Aviation', 'First-Line Supervisors of Material-Moving Machine and Vehicle Operators', 'Rail Car Repairers', 'Agricultural Inspectors', 'Transportation Engineers'] 0
# input title: Urban and Regional Planners top 10 predicted titles: ['Urban and Regional Planners', 'Urban and Regional Planners', 'Urban and Regional Planners', 'Geographers', 'Urban and Regional Planners', 'Urban and Regional Planners', 'Urban and Regional Planners', 'Geography Teachers, Postsecondary', 'Urban and Regional Planners', 'Transportation Planners'] 7
# input title: First-Line Supervisors of Non-Retail Sales Workers top 10 predicted titles: ['Wholesale and Retail Buyers, Except Farm Products', 'Industrial Production Managers', 'Merchandise Displayers and Window Trimmers', 'First-Line Supervisors of Non-Retail Sales Workers', 'First-Line Supervisors of Retail Sales Workers', 'Farmers, Ranchers, and Other Agricultural Managers', 'Epidemiologists', 'First-Line Supervisors of Retail Sales Workers', 'Interviewers, Except Eligibility and Loan', 'First-Line Supervisors of Gambling Services Workers'] 1
# input title: Reinforcing Iron and Rebar Workers top 10 predicted titles: ['First-Line Supervisors of Food Preparation and Serving Workers', 'First-Line Supervisors of Farming, Fishing, and Forestry Workers', 'First-Line Supervisors of Construction Trades and Extraction Workers', 'First-Line Supervisors of Construction Trades and Extraction Workers', 'First-Line Supervisors of Farming, Fishing, and Forestry Workers', 'Mobile Heavy Equipment Mechanics, Except Engines', 'Postal Service Mail Sorters, Processors, and Processing Machine Operators', 'Reinforcing Iron and Rebar Workers', 'Hoist and Winch Operators', 'Entertainment and Recreation Managers, Except Gambling'] 1
# input title: Purchasing Agents, Except Wholesale, Retail, and Farm Products top 10 predicted titles: ['Buyers and Purchasing Agents, Farm Products', 'Buyers and Purchasing Agents, Farm Products', 'Wholesale and Retail Buyers, Except Farm Products', 'Sales Managers', 'Sales Representatives, Wholesale and Manufacturing, Except Technical and Scientific Products', 'Buyers and Purchasing Agents, Farm Products', 'Farmers, Ranchers, and Other Agricultural Managers', 'Chief Executives', 'Retail Salespersons', 'Purchasing Managers'] 0
# input title: Machine Feeders and Offbearers top 10 predicted titles: ['Extruding, Forming, Pressing, and Compacting Machine Setters, Operators, and Tenders', 'Farmworkers, Farm, Ranch, and Aquacultural Animals', 'Animal Caretakers', 'Woodworking Machine Setters, Operators, and Tenders, Except Sawing', 'Cutting and Slicing Machine Setters, Operators, and Tenders', 'Packaging and Filling Machine Operators and Tenders', 'Agricultural Equipment Operators', 'Lathe and Turning Machine Tool Setters, Operators, and Tenders, Metal and Plastic', 'Machine Feeders and Offbearers', 'First-Line Supervisors of Farming, Fishing, and Forestry Workers'] 1
# input title: Calibration Technologists and Technicians top 10 predicted titles: ['Nanotechnology Engineering Technologists and Technicians', 'Computer, Automated Teller, and Office Machine Repairers', 'Electrical and Electronics Repairers, Commercial and Industrial Equipment', 'Calibration Technologists and Technicians', 'Quality Control Analysts', 'Remote Sensing Technicians', 'Automotive Engineers', 'Nuclear Monitoring Technicians', 'Neurodiagnostic Technologists', 'Calibration Technologists and Technicians'] 2

# %%
total_accuracy_FirstModel=sum_FirstModel/500
print("Score for the OpenAi Model",total_accuracy_FirstModel)
# Out:
# Score for the OpenAi Model 0.26

# %% [markdown]
# ### Resources:
#
# 1- https://github.com/ShawnTXin/openai-embeddings
#
# 2- https://www.onetcenter.org/ and https://www.onetcenter.org/dictionary/27.2/excel/task_statements.html
#
# 3- https://platform.openai.com/docs/guides/embeddings/what-are-embeddings
#
# 4-[https://chat.openai.com/chat](https://)
